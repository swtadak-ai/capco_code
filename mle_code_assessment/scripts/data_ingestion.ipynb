# %%
import pandas as pd
import json

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.9 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/9.9 MB 5.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.6/9.9 MB 5.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.6/9.9 MB 5.4 MB/s eta 0:00:02
#    --------------- ------------------------ 3.9/9.9 MB 3.8 MB/s eta 0:00:02
#    --------------------- ------------------ 5.2/9.9 MB 4.3 MB/s eta 0:00:02
#    -------------------------- ------------- 6.6/9.9 MB 4.7 MB/s eta 0:00:01
#    ------------------------------ --------- 7.6/9.9 MB 4.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.7/9.9 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 4.9 MB/s eta 0:00:01
# ...

# %%
# with open('c:\\Users\\Admin\\Downloads\\mle_code_assessment\\mle_code_assessment\\data\\crm_events.json','r') as f:
df_crm = pd.read_json('c:\\Users\\Admin\\Downloads\\mle_code_assessment\\mle_code_assessment\\data\\crm_events.json')
# df_cal = json.load(r'mle_code_assessment\data\calendar_events.json')
df_crm
# Out:
#       crm_id                        subject       client_name  \
# 0   CRM-1001            Q1 Portfolio Review        David Park
# 1   CRM-1002          Portfolio Walkthrough      Mark Johnson
# 2   CRM-1003              Introductory Call     Rachel Torres
# 3   CRM-1004           Due Diligence Review  Patricia Langley
# 4   CRM-1005                Investor Update     Kevin O'Brien
# 5   CRM-1006                Pipeline Review               NaN
# 6   CRM-1007           Follow-up Discussion        David Park
# 7   CRM-1008                  Lunch Meeting         Lisa Tran
# 8   CRM-1009             Board Prep Session               NaN
# 9   CRM-1010            Strategy Discussion    Alan Whitfield
# 10  CRM-1011       Annual Allocation Review      Elena Marcos
# 11  CRM-1012      Co-Investment Opportunity      Thomas Grant
# 12  CRM-1013     LP Advisory Committee Prep               NaN
# 13  CRM-1014                 Quick Check-in    Michael Reeves
# ...

# %%
df_crm.shape
# Out:
# (20, 12)

# %%
df_crm.isna()
# Out:
#     crm_id  subject  client_name  client_company  relationship_owner  \
# 0    False    False        False           False               False
# 1    False    False        False           False               False
# 2    False    False        False           False               False
# 3    False    False        False           False               False
# 4    False    False        False           False               False
# 5    False    False         True            True               False
# 6    False    False        False           False               False
# 7    False    False        False           False               False
# 8    False    False         True            True               False
# 9    False    False        False           False               False
# 10   False    False        False           False               False
# 11   False    False        False           False               False
# 12   False    False         True            True               False
# ...

# %%
import os

os.getcwd()
# Out:
# 'c:\\Users\\Admin\\Downloads\\mle_code_assessment\\mle_code_assessment\\scripts'

# %%
df_cal = pd.read_json('c:\\Users\\Admin\\Downloads\\mle_code_assessment\\mle_code_assessment\\data\\calendar_events.json')
df_cal
# Out:
#    event_id                                      title  \
# 0    CAL-A1     Q1 Portfolio Review - Meridian Capital
# 1    CAL-A2     Summit Advisors - Portfolio Discussion
# 2    CAL-A3                           Weekly Team Sync
# 3    CAL-A4            Crestview Holdings - DD Meeting
# 4    CAL-A5                 Investor Update - Pinnacle
# 5    CAL-A6                 Pinnacle Group - Q1 Update
# 6    CAL-A7                   Internal Pipeline Review
# 7    CAL-A8               Meridian Capital - Follow-up
# 8    CAL-A9                       Atlas Ventures Lunch
# 9   CAL-A10           Board Prep - Q1 Materials Review
# 10  CAL-A11                           Client Reception
# 11  CAL-A12           Horizon Wealth - Year-End Review
# 12  CAL-A13       Granite Point - Co-Invest Discussion
# 13  CAL-A14                  LPAC Prep Working Session
# 14  CAL-A15                Michael Reeves - Quick Sync
# 15  CAL-A16  Atlas Ventures - Infrastructure Deep Dive
# ...

# %%
df_cal.shape
# Out:
# (22, 11)

# %%
df_cal.isna()
# Out:
#     event_id  title  organizer  attendees  start_time  end_time  location  \
# 0      False  False      False      False       False     False     False
# 1      False  False      False      False       False     False     False
# 2      False  False      False      False       False     False     False
# 3      False  False      False      False       False     False     False
# 4      False  False      False      False       False     False     False
# 5      False  False      False      False       False     False     False
# 6      False  False      False      False       False     False     False
# 7      False  False      False      False       False     False     False
# 8      False  False      False      False       False     False     False
# 9      False  False      False      False       False     False     False
# 10     False  False      False      False       False     False      True
# 11     False  False      False      False       False     False     False
# ...

# %%
df_cal.dropna(subset=['description'],inplace=True)
df_cal
# Out:
#    event_id                                      title  \
# 0    CAL-A1     Q1 Portfolio Review - Meridian Capital
# 1    CAL-A2     Summit Advisors - Portfolio Discussion
# 2    CAL-A3                           Weekly Team Sync
# 3    CAL-A4            Crestview Holdings - DD Meeting
# 4    CAL-A5                 Investor Update - Pinnacle
# 5    CAL-A6                 Pinnacle Group - Q1 Update
# 6    CAL-A7                   Internal Pipeline Review
# 7    CAL-A8               Meridian Capital - Follow-up
# 8    CAL-A9                       Atlas Ventures Lunch
# 9   CAL-A10           Board Prep - Q1 Materials Review
# 11  CAL-A12           Horizon Wealth - Year-End Review
# 12  CAL-A13       Granite Point - Co-Invest Discussion
# 13  CAL-A14                  LPAC Prep Working Session
# 14  CAL-A15                Michael Reeves - Quick Sync
# 15  CAL-A16  Atlas Ventures - Infrastructure Deep Dive
# 16  CAL-A17                    ESG + Compliance Review
# ...

# %%
df_cal[df_cal['description']=='Standing weekly sync.']
# Out:
#    event_id             title             organizer  \
# 2    CAL-A3  Weekly Team Sync  sarah.chen@firma.com
# 17  CAL-A18  Weekly Team Sync  sarah.chen@firma.com
#
#                                             attendees           start_time  \
# 2   (sarah.chen@firma.com, james.wu@firma.com, pri...  2025-03-11T09:00:00
# 17  (sarah.chen@firma.com, james.wu@firma.com, pri...  2025-03-18T09:00:00
#
#                end_time                   location            description  \
# 2   2025-03-11T09:30:00  Virtual - Microsoft Teams  Standing weekly sync.
# 17  2025-03-18T09:30:00  Virtual - Microsoft Teams  Standing weekly sync.
#
#     is_recurring     status                created_at
# 2           True  confirmed 2025-01-06 08:00:00+00:00
# 17          True  confirmed 2025-01-06 08:00:00+00:00

# %%
df_cal.columns
# Out:
# Index(['event_id', 'title', 'organizer', 'attendees', 'start_time', 'end_time',
#        'location', 'description', 'is_recurring', 'status', 'created_at'],
#       dtype='str')

# %%
duplicates = df_cal[df_cal.duplicated(subset=['title', 'organizer', 'start_time', 'end_time',
       'location', 'description', 'is_recurring', 'status'])]

# %%
duplicates
# Out:
# Empty DataFrame
# Columns: [event_id, title, organizer, attendees, start_time, end_time, location, description, is_recurring, status, created_at]
# Index: []

# %%
from rapidfuzz import fuzz

# %%
df_final= pd.DataFrame()

# %%
df_final['tital_smilarity'] = fuzz.ratio(crm_subject, cal_title)

# %%
df_cal.drop_duplicates(subset=['title', 'organizer', 'attendees', 'start_time', 'end_time',
       'location', 'description', 'is_recurring', 'status', 'created_at'],keep='last',inplace=True)
df_cal
# Out:
#    event_id                                      title  \
# 0    CAL-A1     Q1 Portfolio Review - Meridian Capital
# 1    CAL-A2     Summit Advisors - Portfolio Discussion
# 2    CAL-A3                           Weekly Team Sync
# 3    CAL-A4            Crestview Holdings - DD Meeting
# 4    CAL-A5                 Investor Update - Pinnacle
# 5    CAL-A6                 Pinnacle Group - Q1 Update
# 6    CAL-A7                   Internal Pipeline Review
# 7    CAL-A8               Meridian Capital - Follow-up
# 8    CAL-A9                       Atlas Ventures Lunch
# 9   CAL-A10           Board Prep - Q1 Materials Review
# 11  CAL-A12           Horizon Wealth - Year-End Review
# 12  CAL-A13       Granite Point - Co-Invest Discussion
# 13  CAL-A14                  LPAC Prep Working Session
# 14  CAL-A15                Michael Reeves - Quick Sync
# 15  CAL-A16  Atlas Ventures - Infrastructure Deep Dive
# 16  CAL-A17                    ESG + Compliance Review
# ...

# %%
df_cal['attendees']=df_cal['attendees'].apply(tuple)
df_cal
# Out:
#    event_id                                      title  \
# 0    CAL-A1     Q1 Portfolio Review - Meridian Capital
# 1    CAL-A2     Summit Advisors - Portfolio Discussion
# 2    CAL-A3                           Weekly Team Sync
# 3    CAL-A4            Crestview Holdings - DD Meeting
# 4    CAL-A5                 Investor Update - Pinnacle
# 5    CAL-A6                 Pinnacle Group - Q1 Update
# 6    CAL-A7                   Internal Pipeline Review
# 7    CAL-A8               Meridian Capital - Follow-up
# 8    CAL-A9                       Atlas Ventures Lunch
# 9   CAL-A10           Board Prep - Q1 Materials Review
# 11  CAL-A12           Horizon Wealth - Year-End Review
# 12  CAL-A13       Granite Point - Co-Invest Discussion
# 13  CAL-A14                  LPAC Prep Working Session
# 14  CAL-A15                Michael Reeves - Quick Sync
# 15  CAL-A16  Atlas Ventures - Infrastructure Deep Dive
# 16  CAL-A17                    ESG + Compliance Review
# ...

# %%
df_cal.dtypes
# Out:
# event_id                        str
# title                           str
# organizer                       str
# attendees                    object
# start_time                      str
# end_time                        str
# location                        str
# description                     str
# is_recurring                   bool
# status                          str
# created_at      datetime64[us, UTC]
# dtype: object

# %%
df_cal['date']=pd.to_datetime(df_cal['start_time'],utc=True,format='ISO8601').dt.date
df_cal['date']
# Out:
# 0     2025-03-10
# 1     2025-03-12
# 2     2025-03-11
# 3     2025-03-13
# 4     2025-03-17
# 5     2025-03-17
# 6     2025-03-14
# 7     2025-03-18
# 8     2025-03-15
# 9     2025-03-19
# 11    2025-03-21
# 12    2025-03-21
# 13    2025-03-24
# 14    2025-03-25
# 15    2025-03-26
# 16    2025-03-27
# 17    2025-03-18
# 18    2025-03-28
# 19    2025-03-28
# 20    2025-03-25
# 21    2025-04-01
# Name: date, dtype: object

# %%
df_cal.columns
# Out:
# Index(['event_id', 'title', 'organizer', 'attendees', 'start_time', 'end_time',
#        'location', 'description', 'is_recurring', 'status', 'created_at',
#        'date'],
#       dtype='str')

# %%
df_cal.shape
# Out:
# (21, 11)

# %%
df_cal.drop_duplicates(subset=['title', 'organizer', 'attendees', 'start_time', 'end_time',
       'location', 'description', 'is_recurring', 'status', 'created_at'],keep='last',inplace=True)
df_cal
# Out:
#    event_id                                      title  \
# 0    CAL-A1     Q1 Portfolio Review - Meridian Capital
# 1    CAL-A2     Summit Advisors - Portfolio Discussion
# 2    CAL-A3                           Weekly Team Sync
# 3    CAL-A4            Crestview Holdings - DD Meeting
# 4    CAL-A5                 Investor Update - Pinnacle
# 5    CAL-A6                 Pinnacle Group - Q1 Update
# 6    CAL-A7                   Internal Pipeline Review
# 7    CAL-A8               Meridian Capital - Follow-up
# 8    CAL-A9                       Atlas Ventures Lunch
# 9   CAL-A10           Board Prep - Q1 Materials Review
# 11  CAL-A12           Horizon Wealth - Year-End Review
# 12  CAL-A13       Granite Point - Co-Invest Discussion
# 13  CAL-A14                  LPAC Prep Working Session
# 14  CAL-A15                Michael Reeves - Quick Sync
# 15  CAL-A16  Atlas Ventures - Infrastructure Deep Dive
# 16  CAL-A17                    ESG + Compliance Review
# ...

# %%
duplicates = df_cal[df_cal.duplicated(subset=['title', 'organizer', 'attendees', 'start_time', 'end_time',
       'location', 'description', 'is_recurring', 'status', 'created_at'])]

# %%
duplicates
# Out:
# Empty DataFrame
# Columns: [event_id, title, organizer, attendees, start_time, end_time, location, description, is_recurring, status, created_at]
# Index: []

# %%
df_cal[df_cal['description']=='Standing weekly sync.']
# Out:
#    event_id             title             organizer  \
# 2    CAL-A3  Weekly Team Sync  sarah.chen@firma.com
# 17  CAL-A18  Weekly Team Sync  sarah.chen@firma.com
#
#                                             attendees           start_time  \
# 2   (sarah.chen@firma.com, james.wu@firma.com, pri...  2025-03-11T09:00:00
# 17  (sarah.chen@firma.com, james.wu@firma.com, pri...  2025-03-18T09:00:00
#
#                end_time                   location            description  \
# 2   2025-03-11T09:30:00  Virtual - Microsoft Teams  Standing weekly sync.
# 17  2025-03-18T09:30:00  Virtual - Microsoft Teams  Standing weekly sync.
#
#     is_recurring     status                created_at
# 2           True  confirmed 2025-01-06 08:00:00+00:00
# 17          True  confirmed 2025-01-06 08:00:00+00:00

# %%
df_crm.columns
# Out:
# Index(['crm_id', 'subject', 'client_name', 'client_company',
#        'relationship_owner', 'meeting_date', 'meeting_time', 'meeting_type',
#        'location', 'notes', 'status', 'created_at'],
#       dtype='str')

# %%
df_crm
# Out:
#       crm_id                        subject       client_name  \
# 0   CRM-1001            Q1 Portfolio Review        David Park
# 1   CRM-1002          Portfolio Walkthrough      Mark Johnson
# 2   CRM-1003              Introductory Call     Rachel Torres
# 3   CRM-1004           Due Diligence Review  Patricia Langley
# 4   CRM-1005                Investor Update     Kevin O'Brien
# 5   CRM-1006                Pipeline Review               NaN
# 6   CRM-1007           Follow-up Discussion        David Park
# 7   CRM-1008                  Lunch Meeting         Lisa Tran
# 8   CRM-1009             Board Prep Session               NaN
# 9   CRM-1010            Strategy Discussion    Alan Whitfield
# 10  CRM-1011       Annual Allocation Review      Elena Marcos
# 11  CRM-1012      Co-Investment Opportunity      Thomas Grant
# 12  CRM-1013     LP Advisory Committee Prep               NaN
# 13  CRM-1014                 Quick Check-in    Michael Reeves
# ...

# %%
df_cal.columns
# Out:
# Index(['event_id', 'title', 'organizer', 'attendees', 'start_time', 'end_time',
#        'location', 'description', 'is_recurring', 'status', 'created_at'],
#       dtype='str')

# %%
df_cal_sub=df_cal[['event_id','title','organizer','attendees','description','date']]

# %%
df_cal_sub
# Out:
#    event_id                                      title  \
# 0    CAL-A1     Q1 Portfolio Review - Meridian Capital
# 1    CAL-A2     Summit Advisors - Portfolio Discussion
# 2    CAL-A3                           Weekly Team Sync
# 3    CAL-A4            Crestview Holdings - DD Meeting
# 4    CAL-A5                 Investor Update - Pinnacle
# 5    CAL-A6                 Pinnacle Group - Q1 Update
# 6    CAL-A7                   Internal Pipeline Review
# 7    CAL-A8               Meridian Capital - Follow-up
# 8    CAL-A9                       Atlas Ventures Lunch
# 9   CAL-A10           Board Prep - Q1 Materials Review
# 11  CAL-A12           Horizon Wealth - Year-End Review
# 12  CAL-A13       Granite Point - Co-Invest Discussion
# 13  CAL-A14                  LPAC Prep Working Session
# 14  CAL-A15                Michael Reeves - Quick Sync
# 15  CAL-A16  Atlas Ventures - Infrastructure Deep Dive
# 16  CAL-A17                    ESG + Compliance Review
# ...

# %%
df_crm
# Out:
#       crm_id                        subject       client_name  \
# 0   CRM-1001            Q1 Portfolio Review        David Park
# 1   CRM-1002          Portfolio Walkthrough      Mark Johnson
# 2   CRM-1003              Introductory Call     Rachel Torres
# 3   CRM-1004           Due Diligence Review  Patricia Langley
# 4   CRM-1005                Investor Update     Kevin O'Brien
# 5   CRM-1006                Pipeline Review               NaN
# 6   CRM-1007           Follow-up Discussion        David Park
# 7   CRM-1008                  Lunch Meeting         Lisa Tran
# 8   CRM-1009             Board Prep Session               NaN
# 9   CRM-1010            Strategy Discussion    Alan Whitfield
# 10  CRM-1011       Annual Allocation Review      Elena Marcos
# 11  CRM-1012      Co-Investment Opportunity      Thomas Grant
# 12  CRM-1013     LP Advisory Committee Prep               NaN
# 13  CRM-1014                 Quick Check-in    Michael Reeves
# ...

# %%
df_crm.columns
# Out:
# Index(['crm_id', 'subject', 'client_name', 'client_company',
#        'relationship_owner', 'meeting_date', 'meeting_time', 'meeting_type',
#        'location', 'notes', 'status', 'created_at'],
#       dtype='str')

# %%
df_crm_sub=df_crm[['crm_id','subject','notes','client_name','relationship_owner','meeting_date']]
df_crm_sub
# Out:
#       crm_id                        subject  \
# 0   CRM-1001            Q1 Portfolio Review
# 1   CRM-1002          Portfolio Walkthrough
# 2   CRM-1003              Introductory Call
# 3   CRM-1004           Due Diligence Review
# 4   CRM-1005                Investor Update
# 5   CRM-1006                Pipeline Review
# 6   CRM-1007           Follow-up Discussion
# 7   CRM-1008                  Lunch Meeting
# 8   CRM-1009             Board Prep Session
# 9   CRM-1010            Strategy Discussion
# 10  CRM-1011       Annual Allocation Review
# 11  CRM-1012      Co-Investment Opportunity
# 12  CRM-1013     LP Advisory Committee Prep
# 13  CRM-1014                 Quick Check-in
# 14  CRM-1015      Infrastructure Fund Pitch
# 15  CRM-1016      ESG Compliance Discussion
# 16  CRM-1017                 Closing Dinner
# 17  CRM-1018                 Follow-up Call
# 18  CRM-1019      Quarterly Business Review
# 19  CRM-1020  Northwind - Fund VII Interest
#
# ...

# %%
df_crm_sub['meeting_date']=df_crm_sub['meeting_date'] = df_crm_sub['meeting_date'].apply(
    lambda x: x.replace('//', '-') if '//' in x else x
)

# %%
df_crm_sub
# Out:
#       crm_id                        subject  \
# 0   CRM-1001            Q1 Portfolio Review
# 1   CRM-1002          Portfolio Walkthrough
# 2   CRM-1003              Introductory Call
# 3   CRM-1004           Due Diligence Review
# 4   CRM-1005                Investor Update
# 5   CRM-1006                Pipeline Review
# 6   CRM-1007           Follow-up Discussion
# 7   CRM-1008                  Lunch Meeting
# 8   CRM-1009             Board Prep Session
# 9   CRM-1010            Strategy Discussion
# 10  CRM-1011       Annual Allocation Review
# 11  CRM-1012      Co-Investment Opportunity
# 12  CRM-1013     LP Advisory Committee Prep
# 13  CRM-1014                 Quick Check-in
# 14  CRM-1015      Infrastructure Fund Pitch
# 15  CRM-1016      ESG Compliance Discussion
# 16  CRM-1017                 Closing Dinner
# 17  CRM-1018                 Follow-up Call
# 18  CRM-1019      Quarterly Business Review
# 19  CRM-1020  Northwind - Fund VII Interest
#
# ...

# %%
df_cal_sub
# Out:
#    event_id                                      title  \
# 0    CAL-A1     Q1 Portfolio Review - Meridian Capital
# 1    CAL-A2     Summit Advisors - Portfolio Discussion
# 2    CAL-A3                           Weekly Team Sync
# 3    CAL-A4            Crestview Holdings - DD Meeting
# 4    CAL-A5                 Investor Update - Pinnacle
# 5    CAL-A6                 Pinnacle Group - Q1 Update
# 6    CAL-A7                   Internal Pipeline Review
# 7    CAL-A8               Meridian Capital - Follow-up
# 8    CAL-A9                       Atlas Ventures Lunch
# 9   CAL-A10           Board Prep - Q1 Materials Review
# 11  CAL-A12           Horizon Wealth - Year-End Review
# 12  CAL-A13       Granite Point - Co-Invest Discussion
# 13  CAL-A14                  LPAC Prep Working Session
# 14  CAL-A15                Michael Reeves - Quick Sync
# 15  CAL-A16  Atlas Ventures - Infrastructure Deep Dive
# 16  CAL-A17                    ESG + Compliance Review
# ...

# %%
df_cal_sub['organizer'] = df_cal_sub["organizer"].apply(lambda x : x.split("@")[0])
df_cal_sub['organizer'] = df_cal_sub['organizer'] .apply(lambda x: x.replace(".", " "))
